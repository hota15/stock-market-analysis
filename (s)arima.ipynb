# %% [markdown]
# <a href="https://colab.research.google.com/github/hota15/Time-Series-stock-market-analysis/blob/Tanisha/(s)arima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Prepare the data
dftrain=pd.read_csv("TimeSeriesDataset.csv")

fig, axes = plt.subplots(3, 2, sharex = True)
axes[0, 0].plot(dftrain['HAL_Volume'])
axes[0, 0].set_title('The Genuine Series')
plot_acf(dftrain['HAL_Volume'], ax=axes[0,1]);


dates = pd.to_datetime(dftrain['HAL_Volume'])
values =dftrain['HAL_Volume']
series = pd.Series(values.values, index=dates)

# Determine the optimal values for p and q using ACF and PACF plots
plot_acf(series)
plt.show()

plot_pacf(series)
plt.show()

# Grid search to find the optimal values for p, d, and q
best_aic = np.inf
best_order = None

for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                model = ARIMA(series, order=(p, d, q))
                model_fit = model.fit()
                aic = model_fit.aic

                if aic < best_aic:
                    best_aic = aic
                    best_order = (p, d, q)
            except:
                   continue
print(f"Optimal (p, d, q) values: {best_order}")
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Prepare the data
fig, axes = plt.subplots(3, 2, sharex = True)
axes[0, 0].plot(dftrain['HAL_Volume'])
axes[0, 0].set_title('The Genuine Series')
plot_acf(dftrain['HAL_Volume'], ax=axes[0,1]);
dftrain=pd.read_csv("TimeSeriesDataset.csv")
dates = pd.to_datetime(dftrain['HAL_Volume'])
values =dftrain['HAL_Volume']
series = pd.Series(values.values, index=dates)

# Determine the optimal values for p and q using ACF and PACF plots
plot_acf(series)
plt.show()

plot_pacf(series)
plt.show()

# Grid search to find the optimal values for p, d, and q
best_aic = np.inf
best_order = None

for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                model = ARIMA(series, order=(p, d, q))
                model_fit = model.fit()
                aic = model_fit.aic

                if aic < best_aic:
                    best_aic = aic
                    best_order = (p, d, q)
            except:
                   continue
print(f"Optimal (p, d, q) values: {best_order}")
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Prepare the data
dftrain=pd.read_csv("TimeSeriesDataset.csv")
dates = pd.to_datetime(dftrain['HAL_Volume'])
values =dftrain['HAL_Volume']
series = pd.Series(values.values, index=dates)



# Fit the ARIMA model
order = (1,1,1)
model = ARIMA(dftrain['HAL_Volume'], order=order)
model_fit = model.fit()

print(model_fit.summary())
predictions = model_fit.predict()

# Forecast the next 39 values
forecast = model_fit.forecast(steps=39)

# Print the forecasted values
print(forecast)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:             HAL_Volume   No. Observations:                  253
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3994.880
# Date:                Tue, 03 Oct 2023   AIC                           7995.761
# Time:                        11:28:19   BIC                           8006.349
# Sample:                             0   HQIC                          8000.021
#                                 - 253
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3649      0.065      5.601      0.000       0.237       0.493
# ma.L1         -0.8491      0.031    -27.149      0.000      -0.910      -0.788
# sigma2      3.746e+12   4.68e-15   8.01e+26      0.000    3.75e+12    3.75e+12
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error, mean_absolute_error

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Prepare the data
dftrain=pd.read_csv("TimeSeriesDataset.csv")

def mae(y_true, predictions):
    y_true, predictions = np.array(y_true), np.array(predictions)
    return np.mean(np.abs(y_true - predictions))

def mape(y_test, pred):
    y_test, pred = np.array(y_test), np.array(pred)
    mape = np.mean(np.abs((y_test - pred) / y_test))
    return mape

MAE= mae(dftrain['HAL_Volume'], predictions)
print("MAE:", MAE)
mape = mape(dftrain['HAL_Volume'],predictions) * 100
print("MAPE:",mape)



plt.figure(figsize=(20,6))
plt.plot(dftrain['HAL_Volume'], label='Actual',linewidth=2)
plt.plot(predictions, label='Predicted',linewidth=5)

plt.xlabel('Trend')
plt.ylabel('Value')
plt.title('ARIMA Model')
plt.legend()
plt.show()
# Out:
# MAE: 948444.0190523438
# MAPE: 73.75950903101806

# %%
from tqdm.notebook import trange, tqdm


def optimize_SARIMA(parameters_list, d, D, s, exog):

    results = []

    for param in tqdm.notebook(parameters_list):
        try:
            model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue

        aic = model.aic
        results.append([param, aic])

    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']

    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    return result_df

# %%
from itertools import product
import statsmodels.api as sm
p = range(0,1,1)
d = 1
q = range(0, 2, 1)
P = range(0, 1, 1)
D = 1
Q = range(0, 2, 1)
s = 4
parameters=product(p,q,P,Q)
parameters_list = list(parameters)
print(len(parameters_list))
# Out:
# 4

# %%
def optimize_SARIMA(parameters_list, d, D, s, exog):

    results = []

    for param in tqdm.notebook(parameters_list):
        try:
            model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue

        aic = model.aic
        results.append([param, aic])

    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']

    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)
    return result_df

# %%
result_df = optimize_SARIMA(parameters_list, 1, 1, 2,dftrain['HAL_Volume'] )
result_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-55aeca45b433> in <cell line: 1>()
# ----> 1 result_df = optimize_SARIMA(parameters_list, 1, 1, 2,dftrain['HAL_Volume'] )
#       2 result_df
#
# <ipython-input-48-2fd927365fb1> in optimize_SARIMA(parameters_list, d, D, s, exog)
#       3     results = []
#       4
# ----> 5     for param in tqdm.notebook(parameters_list):
#       6         try:
#       7             model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
#
# AttributeError: type object 'tqdm_notebook' has no attribute 'notebook'

# %%
best_model = SARIMAX(dftrain['Volume'], order=(0, 1, 1), seasonal_order=(3,1,3,4)).fit(dis=-1)
print(best_model.summary())

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("TimeSeriesDataset.csv")
start_date='02/04/2018'
end_date='07/02/2022'
mask=(df['Dat+A1:G241e']>=start_date)&(df['Dat+A1:G241e']<=end_date)
dftrain=df.loc[mask]

# %%
import pandas as pd
from prophet import Prophet
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error, mean_absolute_error, r2_score

import numpy as np
import pandas as pd
df=pd.read_csv("TimeSeriesDataset.csv")
start_date='02/04/2018'
end_date='07/02/2022'
mask=(df['Dat+A1:G241e']>=start_date)&(df['Dat+A1:G241e']<=end_date)
dftrain=df.loc[mask]
# Rename the columns to 'ds' and 'y' for the time series data and target variable
#dftrainnew = dftrainnew.rename(columns={'Order Date': 'ds', 'Sales': 'y'})
dftrain = dftrain.rename(columns={'Dat+A1:G241e': 'ds', 'HAL_Volume':'y'})

# Initialize the Prophet model
model = Prophet(weekly_seasonality=True)
model.add_seasonality(name='weekly', period=7, fourier_order=3)  # Example: Weekly seasonality with period 7


# Fit the model to the data
model.fit(dftrain)

# Make predictions
forecast = model.predict()

actual_values = dftrain['y'].values
predicted_values = forecast['yhat'].values

# Print the forecasted values
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-cec19faf87ae> in <cell line: 22>()
#      20
#      21 # Fit the model to the data
# ---> 22 model.fit(dftrain)
#      23
#      24 # Make predictions
#
# /usr/local/lib/python3.10/dist-packages/prophet/forecaster.py in fit(self, df, **kwargs)
#    1121         history = df[df['y'].notnull()].copy()
#    1122         if history.shape[0] < 2:
# -> 1123             raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1124         self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
#    1125
#
# ValueError: Dataframe has less than 2 non-NaN rows.
